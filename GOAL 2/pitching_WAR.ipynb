# %% [markdown]
# Installing necessary libraries

# %%
# !pip install os
# !pip install pandas
# !pip install numpy
# !pip install pybaseball
# Out:
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Collecting pybaseball
#   Downloading pybaseball-2.2.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (1.26.4)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (2.2.2)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (4.13.3)
# Requirement already satisfied: requests>=2.18.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (2.32.3)
# Requirement already satisfied: lxml>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (5.3.1)
# Requirement already satisfied: pyarrow>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (18.1.0)
# Collecting pygithub>=1.51 (from pybaseball)
#   Downloading PyGithub-2.6.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (1.14.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (3.10.0)
# Requirement already satisfied: tqdm>=4.50.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (4.67.1)
# Requirement already satisfied: attrs>=20.3.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (25.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.0->pybaseball) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.0->pybaseball) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.3->pybaseball) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.3->pybaseball) (2025.1)
# Collecting pynacl>=1.4.0 (from pygithub>=1.51->pybaseball)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (2.10.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pygithub>=1.51->pybaseball) (2.3.0)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from pygithub>=1.51->pybaseball) (1.2.18)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (2025.1.31)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball) (1.17.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball) (1.17.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->pygithub>=1.51->pybaseball) (1.17.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball) (2.22)
# Downloading pybaseball-2.2.7-py3-none-any.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.1/426.1 kB 6.8 MB/s eta 0:00:00
# Downloading PyGithub-2.6.1-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 29.2 MB/s eta 0:00:00
# Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 33.6 MB/s eta 0:00:00
# Installing collected packages: pynacl, pygithub, pybaseball
# Successfully installed pybaseball-2.2.7 pygithub-2.6.1 pynacl-1.5.0

# %% [markdown]
# Importing the installed libraries

# %%
import os
import pandas as pd
import numpy as np
from pybaseball import pitching_stats

# %% [markdown]
# Specifying the start and end seasons we are getting our data from

# %%
START = 2002
END = 2023

# %% [markdown]
# Retrieving data of pitchers who have pitched at least 150 innings any season from 2002 to 2023.

# %%
pitching = pitching_stats(START,END,qual=150)

# %% [markdown]
# Converts pitching to a .csv file and filters pitching

# %%
pitching.to_csv("pitching.csv")
pitching = pitching.groupby("IDfg", group_keys=False).filter(lambda x : x.shape[0] > 1)

# %% [markdown]
# Now you can see our current data

# %%
pitching
# Out:
#        IDfg  Season            Name   Team  Age   W   L  WAR   ERA   G  ...  \
# 86       60    2004   Randy Johnson    ARI   40  16  14  9.6  2.60  35  ...
# 357      73    2002  Curt Schilling    ARI   35  23   7  9.3  3.23  36  ...
# 1     10954    2018    Jacob deGrom    NYM   30  10   9  9.0  1.70  32  ...
# 38     1303    2011    Roy Halladay    PHI   34  19   6  8.7  2.35  32  ...
# 12     1943    2009    Zack Greinke    KCR   25  16   8  8.7  2.16  33  ...
# ...     ...     ...             ...    ...  ...  ..  ..  ...   ...  ..  ...
# 1696   3200    2012   Ervin Santana    LAA   29   9  13 -0.8  5.16  30  ...
# 1825   7541    2013   Lucas Harrell    HOU   28   6  17 -0.9  5.86  36  ...
# 1832   4897    2010    Scott Kazmir    LAA   26   9  15 -1.0  5.94  28  ...
# 1823   7059    2016   James Shields  - - -   34   6  19 -1.0  5.85  33  ...
# 1664    978    2011  Bronson Arroyo    CIN   34   9  12 -1.6  5.07  32  ...
#
#       Pit+ FC  Stf+ FS  Loc+ FS  Pit+ FS  Stuff+  Location+  Pitching+  \
# 86        NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 357       NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 1         NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 38        NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 12        NaN      NaN      NaN      NaN     NaN        NaN        NaN
# ...       ...      ...      ...      ...     ...        ...        ...
# 1696      NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 1825      NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 1832      NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 1823      NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 1664      NaN      NaN      NaN      NaN     NaN        NaN        NaN
#
#       Stf+ FO  Loc+ FO  Pit+ FO
# 86        NaN      NaN      NaN
# 357       NaN      NaN      NaN
# 1         NaN      NaN      NaN
# 38        NaN      NaN      NaN
# 12        NaN      NaN      NaN
# ...       ...      ...      ...
# 1696      NaN      NaN      NaN
# 1825      NaN      NaN      NaN
# 1832      NaN      NaN      NaN
# 1823      NaN      NaN      NaN
# 1664      NaN      NaN      NaN
#
# [1681 rows x 393 columns]

# %%
def next_season(player):
    player = player.sort_values("Season")
    player["Next_WAR"] = player["WAR"].shift(-1)
    return player

pitching = pitching.groupby("IDfg", group_keys=False).apply(next_season)
# Out:
# <ipython-input-8-c683c44523ca>:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   pitching = pitching.groupby("IDfg", group_keys=False).apply(next_season)

# %% [markdown]
# null_count prints all the columns and the number of null values within them

# %%
null_count = pitching.isnull().sum()
print(null_count)
# Out:
# IDfg            0
# Season          0
# Name            0
# Team            0
# Age             0
#              ...
# Pitching+    1542
# Stf+ FO      1681
# Loc+ FO      1681
# Pit+ FO      1681
# Next_WAR      358
# Length: 394, dtype: int64

# %% [markdown]
# Gathers all the columns where there are no null rows

# %%
complete_cols = list(pitching.columns[null_count == 0])
complete_cols
# Out:
# ['IDfg',
#  'Season',
#  'Name',
#  'Team',
#  'Age',
#  'W',
#  'L',
#  'WAR',
#  'ERA',
#  'G',
#  'GS',
#  'CG',
#  'ShO',
#  'SV',
#  'BS',
#  'IP',
#  'TBF',
#  'H',
#  'R',
#  'ER',
#  'HR',
#  'BB',
#  'IBB',
#  'HBP',
#  'WP',
#  'BK',
#  'SO',
#  'GB',
#  'FB',
#  'LD',
#  'IFFB',
#  'Balls',
#  'Strikes',
#  'Pitches',
#  'RS',
#  'IFH',
#  'BU',
#  'BUH',
#  'K/9',
#  'BB/9',
#  'K/BB',
#  'H/9',
#  'HR/9',
#  'AVG',
#  'WHIP',
#  'BABIP',
#  'LOB%',
#  'FIP',
#  'GB/FB',
#  'LD%',
#  'GB%',
#  'FB%',
#  'IFFB%',
#  'HR/FB',
#  'IFH%',
#  'BUH%',
#  'Starting',
#  'Start-IP',
#  'RAR',
#  'Dollars',
#  'tERA',
#  'xFIP',
#  'WPA',
#  '-WPA',
#  '+WPA',
#  'RE24',
#  'REW',
#  'pLI',
#  'inLI',
#  'gmLI',
#  'exLI',
#  'Pulls',
#  'WPA/LI',
#  'Clutch',
#  'FB% 2',
#  'FBv',
#  'wFB',
#  'wFB/C',
#  'O-Swing%',
#  'Z-Swing%',
#  'Swing%',
#  'O-Contact%',
#  'Z-Contact%',
#  'Contact%',
#  'Zone%',
#  'F-Strike%',
#  'SwStr%',
#  'HLD',
#  'SD',
#  'MD',
#  'ERA-',
#  'FIP-',
#  'xFIP-',
#  'K%',
#  'BB%',
#  'SIERA',
#  'RS/9',
#  'E-F',
#  'RA9-WAR',
#  'BIP-Wins',
#  'LOB-Wins',
#  'FDP-Wins',
#  'Age Rng',
#  'K-BB%',
#  'Pull%',
#  'Cent%',
#  'Oppo%',
#  'Soft%',
#  'Med%',
#  'Hard%',
#  'kwERA',
#  'TTO%',
#  'K/9+',
#  'BB/9+',
#  'K/BB+',
#  'H/9+',
#  'HR/9+',
#  'AVG+',
#  'WHIP+',
#  'BABIP+',
#  'LOB%+',
#  'K%+',
#  'BB%+',
#  'LD%+',
#  'GB%+',
#  'FB%+',
#  'HR/FB%+',
#  'Pull%+',
#  'Cent%+',
#  'Oppo%+',
#  'Soft%+',
#  'Med%+',
#  'Hard%+',
#  'Events',
#  'CStr%',
#  'CSW%']

# %% [markdown]
# Puts all the complete columns as well as the Next_WAR column that got removed (since some have null values due to possibility of a year being a player's last season).

# %%
pitching = pitching[complete_cols + ["Next_WAR"]].copy()
pitching
# Out:
#        IDfg  Season             Name Team  Age   W   L  WAR   ERA   G  ...  \
# 805      27    2002      Ramon Ortiz  ANA   29  15   9  1.6  3.77  32  ...
# 1713     27    2003      Ramon Ortiz  ANA   30  16  13  0.8  5.20  32  ...
# 1748     27    2005      Ramon Ortiz  CIN   32   9  11  0.3  5.36  30  ...
# 1789     27    2006      Ramon Ortiz  WSN   33  11  16  0.2  5.57  33  ...
# 301      40    2002  Jarrod Washburn  ANA   27  18   6  4.2  3.15  32  ...
# ...     ...     ...              ...  ...  ...  ..  ..  ...   ...  ..  ...
# 760   22250    2023    Logan Gilbert  SEA   26  13   7  3.1  3.73  32  ...
# 539   23735    2021      Luis Garcia  HOU   24  11   8  3.1  3.48  30  ...
# 749   23735    2022      Luis Garcia  HOU   25  15   8  2.0  3.72  28  ...
# 358   25377    2022     Brady Singer  KCR   25  10   5  3.0  3.23  27  ...
# 1783  25377    2023     Brady Singer  KCR   26   8  11  2.0  5.52  29  ...
#
#       Pull%+  Cent%+  Oppo%+  Soft%+  Med%+  Hard%+  Events  CStr%   CSW%  \
# 805      101      93     106      79    106      97       0  0.139  0.256
# 1713      99     108      94     109     98      99       0  0.152  0.238
# 1748     110     103      80      80    104     104       0  0.147  0.243
# 1789     100     106      91      97    102      96       0  0.148  0.231
# 301       88      90     130      92    103      97       0  0.154  0.233
# ...      ...     ...     ...     ...    ...     ...     ...    ...    ...
# 760      104      97      97      81    104     103     543  0.149  0.271
# 539       98     104      98     108     97     101     413  0.163  0.297
# 749      106      88     107     104     95     106     438  0.157  0.287
# 358       87     109     107      88    101     105     425  0.210  0.303
# 1783     107      96      94      77     95     119     512  0.184  0.279
#
#       Next_WAR
# 805        0.8
# 1713       0.3
# 1748       0.2
# 1789       NaN
# 301        1.6
# ...        ...
# 760        NaN
# 539        2.0
# 749        NaN
# 358        2.0
# 1783       NaN
#
# [1681 rows x 137 columns]

# %%
pitching.dtypes[pitching.dtypes == 'object']
# Out:
# Name       object
# Team       object
# Dollars    object
# Age Rng    object
# dtype: object

# %% [markdown]
# Removes all columns that are of the object datatype since they will not be useful for models input.

# %%
del pitching["Dollars"]
del pitching["Age Rng"]
del pitching["Team"]

# %% [markdown]
# pitching_full contains copy of cleaned pitching dataset and pitching now is filtered with all the null war rows removed

# %%
pitching_full = pitching.copy()
pitching = pitching.dropna()

# %%
pitching
# Out:
#        IDfg  Season             Name  Age   W   L  WAR   ERA   G  GS  ...  \
# 805      27    2002      Ramon Ortiz   29  15   9  1.6  3.77  32  32  ...
# 1713     27    2003      Ramon Ortiz   30  16  13  0.8  5.20  32  32  ...
# 1748     27    2005      Ramon Ortiz   32   9  11  0.3  5.36  30  30  ...
# 301      40    2002  Jarrod Washburn   27  18   6  4.2  3.15  32  32  ...
# 1333     40    2003  Jarrod Washburn   28  10  15  1.6  4.43  32  32  ...
# ...     ...     ...              ...  ...  ..  ..  ...   ...  ..  ..  ...
# 1768  20633    2019    Yusei Kikuchi   28   6  11  0.2  5.46  32  32  ...
# 1321  20633    2021    Yusei Kikuchi   30   7   9  1.1  4.41  29  29  ...
# 330   22250    2022    Logan Gilbert   25  13   6  3.0  3.20  32  32  ...
# 539   23735    2021      Luis Garcia   24  11   8  3.1  3.48  30  28  ...
# 358   25377    2022     Brady Singer   25  10   5  3.0  3.23  27  24  ...
#
#       Pull%+  Cent%+  Oppo%+  Soft%+  Med%+  Hard%+  Events  CStr%   CSW%  \
# 805      101      93     106      79    106      97       0  0.139  0.256
# 1713      99     108      94     109     98      99       0  0.152  0.238
# 1748     110     103      80      80    104     104       0  0.147  0.243
# 301       88      90     130      92    103      97       0  0.154  0.233
# 1333      97      99     106     109     95     108       0  0.172  0.255
# ...      ...     ...     ...     ...    ...     ...     ...    ...    ...
# 1768      98      88     119     107     98     100     549  0.163  0.251
# 1321      99     111      86      69    106     106     436  0.164  0.288
# 330      102      95     104      88     94     117     537  0.144  0.251
# 539       98     104      98     108     97     101     413  0.163  0.297
# 358       87     109     107      88    101     105     425  0.210  0.303
#
#       Next_WAR
# 805        0.8
# 1713       0.3
# 1748       0.2
# 301        1.6
# 1333       2.0
# ...        ...
# 1768       1.1
# 1321       2.4
# 330        3.1
# 539        2.0
# 358        2.0
#
# [1323 rows x 134 columns]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Picks a random player and isolates that player's data in the player_data dataframe

# %%
random_player = np.random.choice(pitching["Name"].unique())
player_data = pitching[pitching["Name"] == random_player].sort_values(by="Season")
player_data
# Out:
#       IDfg  Season          Name  Age   W   L  WAR   ERA   G  GS  ...  Pull%+  \
# 624    225    2002  Mark Buehrle   23  19  12  4.3  3.58  34  34  ...     104
# 1115   225    2003  Mark Buehrle   24  14  14  4.3  4.14  35  35  ...      99
# 915    225    2004  Mark Buehrle   25  16  10  4.5  3.89  35  35  ...     101
# 286    225    2005  Mark Buehrle   26  16   8  5.9  3.12  33  33  ...      96
# 1637   225    2006  Mark Buehrle   27  12  13  1.7  4.99  32  32  ...     105
# 664    225    2007  Mark Buehrle   28  10   9  3.3  3.63  30  30  ...     119
# 828    225    2008  Mark Buehrle   29  15  12  4.2  3.79  34  34  ...     110
# 873    225    2009  Mark Buehrle   30  13  10  3.0  3.84  33  33  ...     108
# 1224   225    2010  Mark Buehrle   31  13  13  3.8  4.28  33  33  ...     106
# 636    225    2011  Mark Buehrle   32  13   9  3.1  3.59  31  31  ...     103
# 767    225    2012  Mark Buehrle   33  13  13  1.6  3.74  31  31  ...     114
# 1126   225    2013  Mark Buehrle   34  12  10  2.2  4.15  33  33  ...     111
# 471    225    2014  Mark Buehrle   35  13  10  3.7  3.39  32  32  ...     115
#
#       Cent%+  Oppo%+  Soft%+  Med%+  Hard%+  Events  CStr%   CSW%  Next_WAR
# 624      106      87     117     99      92       0  0.162  0.255       4.3
# 1115      85     117     103    107      80       0  0.168  0.244       4.5
# 915       97     100     122     96      98       0  0.181  0.262       5.9
# 286       94     113     147     99      77       0  0.182  0.254       1.7
# 1637      95      99     134     95      97       0  0.168  0.229       3.3
# 664       92      81     111    100      94       0  0.171  0.250       4.2
# 828      101      83     115    100      91       0  0.171  0.239       3.0
# 873       95      95      98    109      81       0  0.176  0.242       3.8
# 1224      93     100     124     99      87       0  0.181  0.242       3.1
# 636      108      85     115     95      97       0  0.179  0.244       1.6
# 767       95      85      90     99     108       0  0.191  0.263       2.2
# 1126      95      89      91    101     103       0  0.193  0.263       3.7
# 471       94      84      98    103      96       0  0.189  0.252       2.0
#
# [13 rows x 134 columns]

# %% [markdown]
# Shows a player's WAR over tracked seasons

# %%
plt.figure(figsize=(10,6))
plt.plot(player_data["Season"], player_data["WAR"], marker="o", linestyle="-", label=random_player)

plt.xlabel("Season")
plt.ylabel("WAR")
plt.title(f"WAR Over Seasons for {random_player}")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Shows a player's WAR and ERA over tracked seasons

# %%
fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(player_data["Season"], player_data["WAR"], marker="o", linestyle="-", label="WAR")
ax1.set_xlabel("Season")
ax1.set_ylabel("WAR", color="b")
ax1.tick_params(axis="y", labelcolor="b")

ax2 = ax1.twinx()
ax2.plot(player_data["Season"], player_data["ERA"], marker="s", linestyle="--", color="r", label="ERA")
ax2.set_ylabel("ERA", color="r")
ax2.tick_params(axis="y", labelcolor="r")

plt.title(f"WAR & ERA Over Time for {random_player}")
fig.legend(loc="upper left", bbox_to_anchor=(0.1, 0.9))

plt.grid(True)
plt.show()
